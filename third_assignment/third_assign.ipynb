# %% [markdown]
# # Stat Assignment 3
#
# <ul>
#  <li>Author by Papan Choonhaklai 6210503691</li>
# </ul>

# %% [markdown]
# ## Part 2

# %% [markdown]
# ###Time Spending Records Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_time = pd.read_csv('Time_Spending_Records.csv')
df_time
# Out:
#            date       activity  duration(minute)  classification  day  \
# 0    04/01/2022            นอน               660               3  TUE
# 1    04/01/2022  กินข้าวเที่ยง               120               3  TUE
# 2    04/01/2022  เรียน Network               180               1  TUE
# 3    04/01/2022            นอน                60               3  TUE
# 4    04/01/2022    กินข้าวเย็น                60               3  TUE
# ..          ...            ...               ...             ...  ...
# 581  04/03/2022            นอน                90               3  FRI
# 582  04/03/2022    กินข้าวเย็น                60               3  FRI
# 583  04/03/2022         อาบน้ำ                30               3  FRI
# 584  04/03/2022     เรียน Stat               270               1  FRI
# 585  04/03/2022   เล่นโทรศัพท์                30               2  FRI
#
#      activity desc
# 0            sleep
# 1            Lunch
# 2    Study Network
# 3            sleep
# 4           Dinner
# ...

# %%
df=df_time[["duration(minute)","classification"]].groupby('classification').sum()
df
# Out:
#                 duration(minute)
# classification
# 1                          27895
# 2                          12925
# 3                          45490

# %%
fig=plt.figure()

ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.pie(df, labels=['Group 1','Group 2','Group 3'], autopct='%1.1f%%', startangle=90)
ax.axis('equal')

ax.set_title('Percentage for each group duration')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Percentage for each group duration')

# %%
df=df_time[df_time.classification==1]
df
# Out:
#            date                         activity  duration(minute)  \
# 2    04/01/2022                    เรียน Network               180
# 6    04/01/2022                   ทำการบ้าน stat               240
# 7    05/01/2022                   ทำการบ้าน stat                60
# 9    05/01/2022                   เรียน Embedded               180
# 11   05/01/2022                เรียน Lab Network               180
# ..          ...                              ...               ...
# 570  03/03/2022                เรียน CareerSkill               180
# 574  03/03/2022                       เรียน Stat               270
# 576  04/03/2022                      เรียน Eng 4               120
# 580  04/03/2022  เรียน cloud core infrastructure               120
# 584  04/03/2022                       เรียน Stat               270
#
#      classification  day            activity desc
# 2                 1  TUE            Study Network
# 6                 1  TUE         Do homework Stat
# ...

# %%
df = df[["duration(minute)","activity desc"]].groupby('activity desc',as_index=False).sum()
df
# Out:
#               activity desc  duration(minute)
# 0   Coursara Cloud Engineer              2060
# 1    Do homework Blockchain               960
# 2      Do homework Embedded               620
# 3         Do homework Eng 4              1110
# 4   Do homework Lab Network               900
# 5       Do homework Network               410
# 6      Do homework Parallel              1410
# 7          Do homework Stat              1815
# 8              Midterm exam               285
# 9                     Study              1040
# 10         Study Blockchain              1940
# 11        Study Careerskill              1440
# 12           Study Embedded              3165
# 13              Study Eng 4              1800
# 14        Study Lab Network              1260
# 15            Study Network              1740
# 16           Study Parallel              1170
# 17               Study Stat              2190
# 18              Work exceed              2580

# %%
fig=plt.figure()

ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.pie(df["duration(minute)"], labels=df['activity desc'], autopct='%1.1f%%', startangle=90)
ax.axis('equal')

ax.set_title('Percentage of activity in group 1(Study)')
# Out:
# Text(0.5, 1.0, 'Percentage of activity in group 1(Study)')

# %%
df=df_time[df_time.classification==2]
df
# Out:
#            date      activity  duration(minute)  classification  day  \
# 5    04/01/2022  เล่นโทรศัพท์               120               2  TUE
# 14   05/01/2022  เล่นโทรศัพท์                90               2  WED
# 16   05/01/2022   อ่านการ์ตูน                90               2  WED
# 22   06/01/2022     ดูการ์ตูน               120               2  THU
# 26   07/01/2022   อ่านการ์ตูน                60               2  FRI
# ..          ...           ...               ...             ...  ...
# 550  01/03/2022  เล่นโทรศัพท์                90               2  TUE
# 562  02/03/2022        ดูทีวี                90               2  WED
# 566  02/03/2022  เล่นโทรศัพท์                30               2  WED
# 578  04/03/2022    ดู Netflix                60               2  FRI
# 585  04/03/2022  เล่นโทรศัพท์                30               2  FRI
#
#      activity desc
# 5      using phone
# 14     using phone
# 16   Watch cartoon
# 22   Watch cartoon
# 26   Watch cartoon
# ...

# %%
df = df[["duration(minute)","activity desc"]].groupby('activity desc',as_index=False).sum()
df
# Out:
#       activity desc  duration(minute)
# 0          Eat food                60
# 1  Eat food                        15
# 2         Play game               720
# 3          Watch TV              4030
# 4     Watch cartoon              3980
# 5       Watch movie               705
# 6              rest               415
# 7       using phone              3000

# %%
fig=plt.figure()

ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.pie(df["duration(minute)"], labels=df['activity desc'], autopct='%1.1f%%', startangle=90)
ax.axis('equal')

ax.set_title('Percentage of activity in group 2(Relax)')
# Out:
# Text(0.5, 1.0, 'Percentage of activity in group 2(Relax)')

# %%
df=df_time[df_time.classification==3]
df
# Out:
#            date       activity  duration(minute)  classification  day  \
# 0    04/01/2022            นอน               660               3  TUE
# 1    04/01/2022  กินข้าวเที่ยง               120               3  TUE
# 3    04/01/2022            นอน                60               3  TUE
# 4    04/01/2022    กินข้าวเย็น                60               3  TUE
# 8    05/01/2022            นอน               450               3  WED
# ..          ...            ...               ...             ...  ...
# 577  04/03/2022         อาบน้ำ                30               3  FRI
# 579  04/03/2022  กินข้าวเที่ยง                60               3  FRI
# 581  04/03/2022            นอน                90               3  FRI
# 582  04/03/2022    กินข้าวเย็น                60               3  FRI
# 583  04/03/2022         อาบน้ำ                30               3  FRI
#
#     activity desc
# 0           sleep
# 1           Lunch
# 3           sleep
# 4          Dinner
# 8           sleep
# ...

# %%
df = df[["duration(minute)","activity desc"]].groupby('activity desc',as_index=False).sum()
df
# Out:
#   activity desc  duration(minute)
# 0     Breakfast               225
# 1        Dinner              3705
# 2         Lunch              3610
# 3      exercise              1210
# 4      hair cut                15
# 5        shower              1665
# 6         sleep             34220
# 7        travel               840

# %%
fig=plt.figure()

ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.pie(df["duration(minute)"], labels=df['activity desc'], autopct='%1.1f%%', startangle=90)
ax.axis('equal')

ax.set_title('Percentage of activity in group 3(Daily routine)')
# Out:
# Text(0.5, 1.0, 'Percentage of activity in group 3(Daily routine)')

# %% [markdown]
# ###Expense Records Data

# %%
df_money = pd.read_csv('Expense Records.csv')
df_money
# Out:
#            date                item    input  output    week     type
# 0    04/01/2022             เงินต้น  4033.87     NaN  WEEK_1  recieve
# 1    04/01/2022        ซื้อ MCdonal      NaN  176.40  WEEK_1     food
# 2    07/01/2022       ฮาจิบังราเม็ง      NaN  260.00  WEEK_1     food
# 3    07/01/2022             Swensen      NaN  204.00  WEEK_1    snack
# 4    07/01/2022      จ่ายค่าพวงหรีด      NaN  200.00  WEEK_1    other
# ..          ...                 ...      ...     ...     ...      ...
# 108  27/02/2022     จ่ายค่าโทรศัพท์      NaN  322.61  WEEK_8    other
# 109  01/03/2022          ได้รับเงิน  1000.00     NaN  WEEK_9  recieve
# 110  01/03/2022         ซื้อ Subway      NaN  189.00  WEEK_9     food
# 111  02/03/2022  ซื้อ Santafe Steak      NaN  128.00  WEEK_9     food
# 112  04/03/2022  ซื้อ Santafe Steak      NaN  128.00  WEEK_9     food
#
# [113 rows x 6 columns]

# %%
df = df_money[["input","output","type"]].groupby('type',as_index=False).sum()
df
# Out:
#       type     input   output
# 0    drink      0.00   656.00
# 1     food      0.00  7819.90
# 2    other      0.00  4701.54
# 3  recieve  24738.87     0.00
# 4    snack      0.00   510.00
# 5   travel      0.00   672.00

# %%
chart = sns.histplot(data=df_money, x='type')
chart.set(title='numbers of input/output for each types')
# Out:
# [Text(0.5, 1.0, 'numbers of input/output for each types')]

# %%
with open("Expense Records.csv") as f:
  data = f.read().splitlines()
  data = data[1:] #drop header
  print(data)
# Out:
# ['04/01/2022,เงินต้น,4033.87,,WEEK_1,recieve', '04/01/2022,ซื้อ MCdonal,,176.4,WEEK_1,food', '07/01/2022,ฮาจิบังราเม็ง,,260,WEEK_1,food', '07/01/2022,Swensen,,204,WEEK_1,snack', '07/01/2022,จ่ายค่าพวงหรีด,,200,WEEK_1,other', '10/01/2022,จ่าย mpass,,200,WEEK_2,other', '11/01/2022,ได้รับเงิน,3000,,WEEK_2,recieve', '11/01/2022,ซื้อ MCdonal,,171.6,WEEK_2,food', '12/01/2022,ซื้อKFC,,162,WEEK_2,food', '13/01/2022,ซื้อ MCdonal,,177.6,WEEK_2,food', '15/01/2022,ซื้อ Subway,,64,WEEK_2,food', '16/01/2022,ซื้อ Subway,,249,WEEK_2,food', '17/01/2022,ซื้อ Santafe Steak,,178,WEEK_3,food', '20/01/2022,เติมเกม rov,,1500,WEEK_3,other', '21/01/2022,เติมเกม rov,,500,WEEK_3,other', '21/01/2022,ได้รับเงิน,500,,WEEK_3,recieve', '21/01/2022,จ่ายค่าตั๋วหนัง,,149,WEEK_3,other', '21/01/2022,พี่เลี้ยง popcorn,125,,WEEK_3,recieve', '21/01/2022,จ่ายค่าธรรมเนียมขอ transcript,,20,WEEK_3,other', '24/01/2022,ซื้อ MCdonal,,168.6,WEEK_4,food', '26/01/2022,เติมเกม rov,,50,WEEK_4,other', '26/01/2022,จ่ายค่าโทรศัพท์,,319.9
# ...

# %%
l = [[[] for i in range(9)] for j in range(6)]

for record in data:
  record = record.split(",")

  # Type recieve
  if record[5] == 'recieve':
    if record[4] == 'WEEK_1':
      l[0][0].append(float(record[2]))
    elif record[4] == 'WEEK_2':
      l[0][1].append(float(record[2]))
    elif record[4] == 'WEEK_3':
      l[0][2].append(float(record[2]))
    elif record[4] == 'WEEK_4':
      l[0][3].append(float(record[2]))
    elif record[4] == 'WEEK_5':
      l[0][4].append(float(record[2]))
    elif record[4] == 'WEEK_6':
      l[0][5].append(float(record[2]))
    elif record[4] == 'WEEK_7':
      l[0][6].append(float(record[2]))
    elif record[4] == 'WEEK_8':
      l[0][7].append(float(record[2]))
    elif record[4] == 'WEEK_9':
      l[0][8].append(float(record[2]))
    
  # Type food
  elif record[5] == 'food':
    if record[4] == 'WEEK_1':
      l[1][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[1][1].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[1][2].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[1][3].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[1][4].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[1][5].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[1][6].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[1][7].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[1][8].append(float(record[3]))

    # Type snack
  elif record[5] == 'snack':
    if record[4] == 'WEEK_1':
      l[2][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[2][1].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[2][2].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[2][3].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[2][4].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[2][5].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[2][6].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[2][7].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[2][8].append(float(record[3]))

  # Type drink
  elif record[5] == 'drink':
    if record[4] == 'WEEK_1':
      l[3][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[3][1].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[3][2].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[3][3].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[3][4].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[3][5].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[3][6].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[3][7].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[3][8].append(float(record[3]))

  # Type travel
  elif record[5] == 'travel':
    if record[4] == 'WEEK_1':
      l[4][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[4][1].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[4][2].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[4][3].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[4][4].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[4][5].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[4][6].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[4][7].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[4][8].append(float(record[3]))

  # Type other
  elif record[5] == 'other':
    if record[4] == 'WEEK_1':
      l[5][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[5][1].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[5][2].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[5][3].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[5][4].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[5][5].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[5][6].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[5][7].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[5][8].append(float(record[3]))


print(l)
# Out:
# [[[4033.87], [3000.0], [500.0, 125.0], [2000.0], [7000.0, 1000.0, 500.0], [2000.0, 280.0, 1000.0], [2000.0], [300.0], [1000.0]], [[176.4, 260.0], [171.6, 162.0, 177.6, 64.0, 249.0], [178.0], [168.6, 159.0, 228.0], [230.0, 243.0, 221.0, 219.0, 947.0, 479.0, 215.0], [60.0, 175.0, 147.5, 16.0, 16.0, 117.0, 658.0, 108.0], [163.0, 149.5, 140.0, 205.0, 225.0, 83.0], [132.0, 118.0, 16.0, 120.0, 177.7], [189.0, 128.0, 128.0]], [[204.0], [], [], [], [99.0], [], [70.0, 40.0, 32.0], [20.0, 20.0, 25.0], []], [[], [], [], [], [39.0, 20.0], [50.0, 10.0, 59.0, 115.0, 124.0], [131.0, 18.0, 18.0, 12.0], [50.0, 10.0], []], [[], [], [], [], [], [27.0, 32.0, 24.0, 40.0, 35.0, 26.0, 45.0, 32.0, 24.0, 40.0], [45.0, 26.0, 45.0, 12.0, 32.0, 24.0, 40.0], [27.0, 32.0, 24.0, 40.0], []], [[200.0], [200.0], [1500.0, 500.0, 149.0, 20.0], [50.0, 319.93], [], [200.0, 200.0, 500.0, 20.0, 100.0], [150.0, 70.0], [200.0, 322.61], []]]

# %%
for data_class in l:
  for week in data_class:
    print(sum(week))
  print()
# Out:
# 4033.87
# 3000.0
# 625.0
# 2000.0
# 8500.0
# 3280.0
# 2000.0
# 300.0
# 1000.0
#
# 436.4
# 824.2
# 178.0
# 555.6
# 2554.0
# 1297.5
# 965.5
# 563.7
# 445.0
#
# 204.0
# 0
# 0
# 0
# 99.0
# 0
# 142.0
# 65.0
# 0
#
# 0
# 0
# 0
# 0
# 59.0
# 358.0
# 179.0
# 60.0
# 0
#
# 0
# 0
# 0
# 0
# 0
# 325.0
# 224.0
# 123.0
# 0
#
# 200.0
# 200.0
# 2169.0
# 369.93
# 0
# 1020.0
# 220.0
# 522.61
# 0

# %%
spend = []

for i in range(len(l)):
  spend.append([])
  for j in range(len(l[i])):
    spend[i].append(sum(l[i][j]))

print(spend)
# Out:
# [[4033.87, 3000.0, 625.0, 2000.0, 8500.0, 3280.0, 2000.0, 300.0, 1000.0], [436.4, 824.2, 178.0, 555.6, 2554.0, 1297.5, 965.5, 563.7, 445.0], [204.0, 0, 0, 0, 99.0, 0, 142.0, 65.0, 0], [0, 0, 0, 0, 59.0, 358.0, 179.0, 60.0, 0], [0, 0, 0, 0, 0, 325.0, 224.0, 123.0, 0], [200.0, 200.0, 2169.0, 369.93, 0, 1020.0, 220.0, 522.61, 0]]

# %%
df=pd.DataFrame(spend, columns=['WEEK_1','WEEK_2','WEEK_3','WEEK_4','WEEK_5','WEEK_6','WEEK_7','WEEK_8','WEEK_9'] )
df
# Out:
#     WEEK_1  WEEK_2  WEEK_3   WEEK_4  WEEK_5  WEEK_6  WEEK_7  WEEK_8  WEEK_9
# 0  4033.87  3000.0   625.0  2000.00  8500.0  3280.0  2000.0  300.00  1000.0
# 1   436.40   824.2   178.0   555.60  2554.0  1297.5   965.5  563.70   445.0
# 2   204.00     0.0     0.0     0.00    99.0     0.0   142.0   65.00     0.0
# 3     0.00     0.0     0.0     0.00    59.0   358.0   179.0   60.00     0.0
# 4     0.00     0.0     0.0     0.00     0.0   325.0   224.0  123.00     0.0
# 5   200.00   200.0  2169.0   369.93     0.0  1020.0   220.0  522.61     0.0

# %%
df_t=df.T
df_t.columns = ['recieve', 'food', 'snack' , 'drink' , 'travel' , 'other']  
df_t
# Out:
#         recieve    food  snack  drink  travel    other
# WEEK_1  4033.87   436.4  204.0    0.0     0.0   200.00
# WEEK_2  3000.00   824.2    0.0    0.0     0.0   200.00
# WEEK_3   625.00   178.0    0.0    0.0     0.0  2169.00
# WEEK_4  2000.00   555.6    0.0    0.0     0.0   369.93
# WEEK_5  8500.00  2554.0   99.0   59.0     0.0     0.00
# WEEK_6  3280.00  1297.5    0.0  358.0   325.0  1020.00
# WEEK_7  2000.00   965.5  142.0  179.0   224.0   220.00
# WEEK_8   300.00   563.7   65.0   60.0   123.0   522.61
# WEEK_9  1000.00   445.0    0.0    0.0     0.0     0.00

# %%
import pandas as pd

import matplotlib.pyplot as plot

stockIndex = {"week":  ['WEEK_1','WEEK_2','WEEK_3','WEEK_4','WEEK_5','WEEK_6','WEEK_7','WEEK_8','WEEK_9'],
              "food": [436.4,824.2,178.0,555.6,2554.0,1297.5,965.5,563.7,445.0],
              "snack":[204.0, 0, 0, 0, 99.0, 0, 142.0, 65.0, 0],
              "drink":[0, 0, 0, 0, 59.0, 358.0, 179.0, 60.0, 0],
              "travel":[0, 0, 0, 0, 0, 325.0, 224.0, 123.0, 0],
              "other":[200.0, 200.0, 2169.0, 369.93, 0, 1020.0, 220.0, 522.61, 0],
              "recieve":[4033.87, 3000.0, 625.0, 2000.0, 8500.0, 3280.0, 2000.0, 300.0, 1000.0],
              };

df1 = pd.DataFrame(data=stockIndex);
df1.plot.line(x="week", title="Amount of budget for each type in 9 week");

plot.show(block=True);

# %%
from scipy.stats import chi2_contingency
chi2, p, dof, ex = chi2_contingency(df_t)

# %%
chi2
# Out:
# 18714.849250364423

# %%
p
# Out:
# 0.0

# %%
dof
# Out:
# 40

# %%
from scipy.stats import chi2
alpha = 0.05
chi2.ppf(1-alpha, dof)
# Out:
# 55.75847927888702

# %% [markdown]
# ## Part 3

# %% [markdown]
# ###Categorical data analysis (homogeneity)

# %%
import pandas as pd

# %%
with open("Expense Records.csv") as f:
  data = f.read().splitlines()
  data = data[1:] #drop header
  print(data)
# Out:
# ['04/01/2022,เงินต้น,4033.87,,WEEK_1,recieve', '04/01/2022,ซื้อ MCdonal,,176.4,WEEK_1,food', '07/01/2022,ฮาจิบังราเม็ง,,260,WEEK_1,food', '07/01/2022,Swensen,,204,WEEK_1,snack', '07/01/2022,จ่ายค่าพวงหรีด,,200,WEEK_1,other', '10/01/2022,จ่าย mpass,,200,WEEK_2,other', '11/01/2022,ได้รับเงิน,3000,,WEEK_2,recieve', '11/01/2022,ซื้อ MCdonal,,171.6,WEEK_2,food', '12/01/2022,ซื้อKFC,,162,WEEK_2,food', '13/01/2022,ซื้อ MCdonal,,177.6,WEEK_2,food', '15/01/2022,ซื้อ Subway,,64,WEEK_2,food', '16/01/2022,ซื้อ Subway,,249,WEEK_2,food', '17/01/2022,ซื้อ Santafe Steak,,178,WEEK_3,food', '20/01/2022,เติมเกม rov,,1500,WEEK_3,other', '21/01/2022,เติมเกม rov,,500,WEEK_3,other', '21/01/2022,ได้รับเงิน,500,,WEEK_3,recieve', '21/01/2022,จ่ายค่าตั๋วหนัง,,149,WEEK_3,other', '21/01/2022,พี่เลี้ยง popcorn,125,,WEEK_3,recieve', '21/01/2022,จ่ายค่าธรรมเนียมขอ transcript,,20,WEEK_3,other', '24/01/2022,ซื้อ MCdonal,,168.6,WEEK_4,food', '26/01/2022,เติมเกม rov,,50,WEEK_4,other', '26/01/2022,จ่ายค่าโทรศัพท์,,319.9
# ...

# %%
l = [[[] for i in range(3)] for j in range(6)]

for record in data:
  record = record.split(",")

  # Type recieve
  if record[5] == 'recieve':
    if record[4] == 'WEEK_1':
      l[0][0].append(float(record[2]))
    elif record[4] == 'WEEK_2':
      l[0][0].append(float(record[2]))
    elif record[4] == 'WEEK_3':
      l[0][0].append(float(record[2]))
    elif record[4] == 'WEEK_4':
      l[0][1].append(float(record[2]))
    elif record[4] == 'WEEK_5':
      l[0][1].append(float(record[2]))
    elif record[4] == 'WEEK_6':
      l[0][1].append(float(record[2]))
    elif record[4] == 'WEEK_7':
      l[0][2].append(float(record[2]))
    elif record[4] == 'WEEK_8':
      l[0][2].append(float(record[2]))
    elif record[4] == 'WEEK_9':
      l[0][2].append(float(record[2]))
    
  # Type food
  elif record[5] == 'food':
    if record[4] == 'WEEK_1':
      l[1][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[1][0].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[1][0].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[1][1].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[1][1].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[1][1].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[1][2].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[1][2].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[1][2].append(float(record[3]))

    # Type snack
  elif record[5] == 'snack':
    if record[4] == 'WEEK_1':
      l[2][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[2][0].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[2][0].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[2][1].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[2][1].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[2][1].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[2][2].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[2][2].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[2][2].append(float(record[3]))

  # Type drink
  elif record[5] == 'drink':
    if record[4] == 'WEEK_1':
      l[3][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[3][0].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[3][0].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[3][1].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[3][1].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[3][1].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[3][2].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[3][2].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[3][2].append(float(record[3]))

  # Type travel
  elif record[5] == 'travel':
    if record[4] == 'WEEK_1':
      l[4][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[4][0].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[4][0].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[4][1].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[4][1].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[4][1].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[4][2].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[4][2].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[4][2].append(float(record[3]))

  # Type other
  elif record[5] == 'other':
    if record[4] == 'WEEK_1':
      l[5][0].append(float(record[3]))
    elif record[4] == 'WEEK_2':
      l[5][0].append(float(record[3]))
    elif record[4] == 'WEEK_3':
      l[5][0].append(float(record[3]))
    elif record[4] == 'WEEK_4':
      l[5][1].append(float(record[3]))
    elif record[4] == 'WEEK_5':
      l[5][1].append(float(record[3]))
    elif record[4] == 'WEEK_6':
      l[5][1].append(float(record[3]))
    elif record[4] == 'WEEK_7':
      l[5][2].append(float(record[3]))
    elif record[4] == 'WEEK_8':
      l[5][2].append(float(record[3]))
    elif record[4] == 'WEEK_9':
      l[5][2].append(float(record[3]))


print(l)
# Out:
# [[[4033.87, 3000.0, 500.0, 125.0], [2000.0, 7000.0, 1000.0, 500.0, 2000.0, 280.0, 1000.0], [2000.0, 300.0, 1000.0]], [[176.4, 260.0, 171.6, 162.0, 177.6, 64.0, 249.0, 178.0], [168.6, 159.0, 228.0, 230.0, 243.0, 221.0, 219.0, 947.0, 479.0, 215.0, 60.0, 175.0, 147.5, 16.0, 16.0, 117.0, 658.0, 108.0], [163.0, 149.5, 140.0, 205.0, 225.0, 83.0, 132.0, 118.0, 16.0, 120.0, 177.7, 189.0, 128.0, 128.0]], [[204.0], [99.0], [70.0, 40.0, 32.0, 20.0, 20.0, 25.0]], [[], [39.0, 20.0, 50.0, 10.0, 59.0, 115.0, 124.0], [131.0, 18.0, 18.0, 12.0, 50.0, 10.0]], [[], [27.0, 32.0, 24.0, 40.0, 35.0, 26.0, 45.0, 32.0, 24.0, 40.0], [45.0, 26.0, 45.0, 12.0, 32.0, 24.0, 40.0, 27.0, 32.0, 24.0, 40.0]], [[200.0, 200.0, 1500.0, 500.0, 149.0, 20.0], [50.0, 319.93, 200.0, 200.0, 500.0, 20.0, 100.0], [150.0, 70.0, 200.0, 322.61]]]

# %%
for data_class in l:
  for week in data_class:
    print(sum(week))
  print()
# Out:
# 7658.87
# 13780.0
# 3300.0
#
# 1438.6
# 4407.1
# 1974.2
#
# 204.0
# 99.0
# 207.0
#
# 0
# 417.0
# 239.0
#
# 0
# 325.0
# 347.0
#
# 2569.0
# 1389.93
# 742.61

# %%
spend = []

for i in range(len(l)):
  spend.append([])
  for j in range(len(l[i])):
    spend[i].append(len(l[i][j]))

print(spend)
# Out:
# [[4, 7, 3], [8, 18, 14], [1, 1, 6], [0, 7, 6], [0, 10, 11], [6, 7, 4]]

# %%
# # เอาไว้หาจำนวนเงินของแต่ล่ะประเภทที่ใช้ในทุกๆ 3 สัปดาห์
# spend = []

# for i in range(len(l)):
#   spend.append([])
#   for j in range(len(l[i])):
#     spend[i].append(sum(l[i][j]))

# print(spend)
# Out:
# [[7658.87, 13780.0, 3300.0], [1438.6, 4407.1, 1974.2], [204.0, 99.0, 207.0], [0, 417.0, 239.0], [0, 325.0, 347.0], [2569.0, 1389.93, 742.61]]

# %%
df=pd.DataFrame(spend, columns=['WEEK_1-3', 'WEEK_4-6', 'WEEK_7-9'] )
df_t=df.T
df_t.columns = ['recieve', 'food', 'snack' , 'drink' , 'travel' , 'other']  
df_t
# Out:
#           recieve  food  snack  drink  travel  other
# WEEK_1-3        4     8      1      0       0      6
# WEEK_4-6        7    18      1      7      10      7
# WEEK_7-9        3    14      6      6      11      4

# %%
import pandas as pd

import matplotlib.pyplot as plot

stockIndex = {"week":  ["WEEK_1-3", "WEEK_4-6", "WEEK_7-9"],
              "food": [8, 18, 14],
              "snack":[1, 1, 6],
              "drink":[0, 7, 6],
              "travel":[0, 10, 11],
              "other":[6, 7, 4],
              "recieve":[4, 7, 3],
              };

df1 = pd.DataFrame(data=stockIndex);
df1.plot.line(x="week", title="Amount of budget for each type in 9 week");

plot.show(block=True);

# %%
df_t=df_t.drop(columns='recieve')
df_t
# Out:
#           food  snack  drink  travel  other
# WEEK_1-3     8      1      0       0      6
# WEEK_4-6    18      1      7      10      7
# WEEK_7-9    14      6      6      11      4

# %%
import pandas as pd

import matplotlib.pyplot as plot

stockIndex = {"week":  ["WEEK_1-3", "WEEK_4-6", "WEEK_7-9"],
              "food": [1438.6, 4407.1, 1974.2],
              "snack":[204.0, 99.0, 207.0],
              "drink":[0.0, 417.0, 239.0],
              "travel":[0.0, 325.0, 347.0],
              "other":[2569.00, 1389.93, 742.61],
              "recieve":[7658.87, 13780.00, 3300.00],
              };

df1 = pd.DataFrame(data=stockIndex);
df1.plot.line(x="week", title="Amount of budget for each type in 9 week");

plot.show(block=True);

# %%
from scipy.stats import chi2_contingency
chi2, p, dof, ex = chi2_contingency(df_t)

# %%
chi2
# Out:
# 17.1453939577489

# %%
p
# Out:
# 0.028630213890599485

# %%
dof
# Out:
# 8

# %%
from scipy.stats import chi2
alpha = 0.05
chi2.ppf(1-alpha, dof)
# Out:
# 15.50731305586545

# %% [markdown]
# ###Hypothesis test on two data sets

# %% [markdown]
# ทำใน google sheet

# %% [markdown]
# ###Anova on single factor

# %%
import pandas as pd

# %%
with open("Time_Spending_Records.csv") as f:
  data = f.read().splitlines()
  data = data[1:] #drop header
  print(data)
# Out:
# ['04/01/2022,นอน,660,3,TUE,sleep,week 1', '04/01/2022,กินข้าวเที่ยง,120,3,TUE,Lunch,week 1', '04/01/2022,เรียน Network,180,1,TUE,Study Network,week 1', '04/01/2022,นอน,60,3,TUE,sleep,week 1', '04/01/2022,กินข้าวเย็น,60,3,TUE,Dinner,week 1', '04/01/2022,เล่นโทรศัพท์,120,2,TUE,using phone,week 1', '04/01/2022,ทำการบ้าน stat,240,1,TUE,Do homework Stat,week 1', '05/01/2022,ทำการบ้าน stat,60,1,WED,Do homework Stat,week 1', '05/01/2022,นอน,450,3,WED,sleep,week 1', '05/01/2022,เรียน Embedded,180,1,WED,Study Embedded,week 1', '05/01/2022,กินข้าวเที่ยง,60,3,WED,Lunch,week 1', '05/01/2022,เรียน Lab Network,180,1,WED,Study Lab Network,week 1', '05/01/2022,นอน,90,3,WED,sleep,week 1', '05/01/2022,กินข้าวเย็น,60,3,WED,Dinner,week 1', '05/01/2022,เล่นโทรศัพท์,90,2,WED,using phone,week 1', '05/01/2022,ทำการบ้าน Lab Network,120,1,WED,Do homework Lab Network,week 1', '05/01/2022,อ่านการ์ตูน,90,2,WED,Watch cartoon,week 1', '05/01/2022,นอน,30,3,WED,sleep,week 1', '06/01/2022,นอน,540,3,THU,sleep,week 1',
# ...

# %%
# l = [[[] for i in range(7)] for j in range(3)]

# for record in data:
#   record = record.split(",")

#   # Type 1
#   if record[3] == '1':
#     if record[4] == 'MON':
#       l[0][0].append(int(record[2]))
#     elif record[4] == 'TUE':
#       l[0][1].append(int(record[2]))
#     elif record[4] == 'WED':
#       l[0][2].append(int(record[2]))
#     elif record[4] == 'THU':
#       l[0][3].append(int(record[2]))
#     elif record[4] == 'FRI':
#       l[0][4].append(int(record[2]))
#     elif record[4] == 'SAT':
#       l[0][5].append(int(record[2]))
#     elif record[4] == 'SUN':
#       l[0][6].append(int(record[2]))
    
#   # Type 2
#   elif record[3] == '2':
#     if record[4] == 'MON':
#       l[1][0].append(int(record[2]))
#     elif record[4] == 'TUE':
#       l[1][1].append(int(record[2]))
#     elif record[4] == 'WED':
#       l[1][2].append(int(record[2]))
#     elif record[4] == 'THU':
#       l[1][3].append(int(record[2]))
#     elif record[4] == 'FRI':
#       l[1][4].append(int(record[2]))
#     elif record[4] == 'SAT':
#       l[1][5].append(int(record[2]))
#     elif record[4] == 'SUN':
#       l[1][6].append(int(record[2]))
  
#   # Type 3
#   elif record[3] == '3':
#     if record[4] == 'MON':
#       l[2][0].append(int(record[2]))
#     elif record[4] == 'TUE':
#       l[2][1].append(int(record[2]))
#     elif record[4] == 'WED':
#       l[2][2].append(int(record[2]))
#     elif record[4] == 'THU':
#       l[2][3].append(int(record[2]))
#     elif record[4] == 'FRI':
#       l[2][4].append(int(record[2]))
#     elif record[4] == 'SAT':
#       l[2][5].append(int(record[2]))
#     elif record[4] == 'SUN':
#       l[2][6].append(int(record[2]))

# print(l)
# Out:
# [[[150, 120, 60, 150, 90, 180, 150, 240, 120, 90, 150, 60, 240, 120, 180, 90, 180, 120, 180, 180, 120, 180, 210, 120, 180, 270, 120, 180, 210, 90], [180, 240, 180, 210, 120, 180, 120, 180, 240, 180, 120, 180, 200, 180, 180, 270, 180, 300], [60, 180, 180, 120, 180, 270, 60, 480, 90, 240, 120, 120, 60, 180, 60, 150, 180, 180, 180, 180, 180, 180, 180, 180, 80, 180, 180, 270], [180, 180, 300, 180, 180, 225, 120, 180, 150, 75, 150, 180, 180, 180, 120, 180, 180, 270, 180, 180, 180, 180, 180, 60, 180, 180, 270], [180, 120, 120, 150, 120, 120, 180, 90, 270, 150, 120, 60, 120, 120, 150, 120, 150, 120, 150, 240, 120, 330, 120, 120, 270], [30, 150, 150, 180, 150, 120, 240, 150, 120, 240, 150, 120, 240, 200, 270], [60, 270, 60, 135, 210, 60, 60, 180, 240, 120, 240, 240, 120, 240, 120, 120, 240, 200, 120, 240, 270, 120, 200, 240]], [[60, 90, 60, 60, 120, 60, 90, 90, 45, 30, 60, 30], [120, 120, 60, 120, 60, 30, 60, 180, 240, 60, 180, 180, 180, 100, 90, 90, 15, 250, 120, 30, 90], [90, 90, 120, 90, 
# ...

# %%
l = [[[] for i in range(9)] for j in range(3)]

for record in data:
  record = record.split(",")

  # Type 1
  if record[3] == '1':
    if record[6] == 'week 1':
      l[0][0].append(int(record[2]))
    elif record[6] == 'week 2':
      l[0][1].append(int(record[2]))
    elif record[6] == 'week 3':
      l[0][2].append(int(record[2]))
    elif record[6] == 'week 4':
      l[0][3].append(int(record[2]))
    elif record[6] == 'week 5':
      l[0][4].append(int(record[2]))
    elif record[6] == 'week 6':
      l[0][5].append(int(record[2]))
    elif record[6] == 'week 7':
      l[0][6].append(int(record[2]))
    elif record[6] == 'week 8':
      l[0][7].append(int(record[2]))
    elif record[6] == 'week 9':
      l[0][8].append(int(record[2]))
    
  # Type 2
  elif record[3] == '2':
    if record[6] == 'week 1':
      l[1][0].append(int(record[2]))
    elif record[6] == 'week 2':
      l[1][1].append(int(record[2]))
    elif record[6] == 'week 3':
      l[1][2].append(int(record[2]))
    elif record[6] == 'week 4':
      l[1][3].append(int(record[2]))
    elif record[6] == 'week 5':
      l[1][4].append(int(record[2]))
    elif record[6] == 'week 6':
      l[1][5].append(int(record[2]))
    elif record[6] == 'week 7':
      l[1][6].append(int(record[2]))
    elif record[6] == 'week 8':
      l[1][7].append(int(record[2]))
    elif record[6] == 'week 9':
      l[1][8].append(int(record[2]))
  
  # Type 3
  elif record[3] == '3':
    if record[6] == 'week 1':
      l[2][0].append(int(record[2]))
    elif record[6] == 'week 2':
      l[2][1].append(int(record[2]))
    elif record[6] == 'week 3':
      l[2][2].append(int(record[2]))
    elif record[6] == 'week 4':
      l[2][3].append(int(record[2]))
    elif record[6] == 'week 5':
      l[2][4].append(int(record[2]))
    elif record[6] == 'week 6':
      l[2][5].append(int(record[2]))
    elif record[6] == 'week 7':
      l[2][6].append(int(record[2]))
    elif record[6] == 'week 8':
      l[2][7].append(int(record[2]))
    elif record[6] == 'week 9':
      l[2][8].append(int(record[2]))

print(l)
# Out:
# [[[180, 240, 60, 180, 180, 120, 180, 180, 300, 180, 120, 120, 150, 30, 150, 60, 270, 60], [150, 120, 60, 150, 90, 180, 210, 180, 270, 60, 180, 180, 225, 120, 120, 180, 150, 135, 210, 60], [180, 150, 240, 120, 180, 120, 480, 90, 240, 120, 120, 180, 150, 75, 90, 270, 180, 150, 60, 180, 240], [120, 90, 150, 60, 240, 180, 240, 120, 60, 180, 60, 150, 150, 180, 150, 120, 60, 120, 120, 240, 150, 120, 240, 240], [120, 180, 90, 180, 180, 120, 180, 180, 180, 180, 120, 120, 150, 120, 240, 150, 120, 240, 120], [120, 180, 180, 180, 200, 180, 180, 180, 180, 270, 120, 150, 120, 240, 200], [120, 180, 210, 180, 180, 180, 180, 180, 180, 120, 150, 120, 240, 200, 120, 240, 270], [120, 180, 270, 180, 270, 180, 180, 80, 180, 180, 60, 240, 120, 330, 270, 120, 200, 240], [120, 180, 210, 90, 180, 300, 180, 180, 270, 180, 180, 270, 120, 120, 270]], [[120, 90, 90, 120, 60, 150, 60, 60, 60, 300, 60, 120, 120], [60, 120, 60, 120, 60, 30, 120, 90, 60, 120, 75, 60, 60, 90, 120, 60, 120, 90, 180], [90, 60, 180, 75,
# ...

# %%
for data_class in l:
  for week in data_class:
    print(sum(week)/len(week))
  print()
# Out:
# 153.33333333333334
# 151.5
# 172.14285714285714
# 147.5
# 156.31578947368422
# 178.66666666666666
# 179.41176470588235
# 188.88888888888889
# 190.0
#
# 108.46153846153847
# 89.21052631578948
# 111.25
# 110.0
# 137.14285714285714
# 93.25
# 115.66666666666667
# 84.0909090909091
# 55.714285714285715
#
# 177.6
# 164.53125
# 171.0
# 152.72727272727272
# 156.36363636363637
# 136.125
# 143.1081081081081
# 151.44736842105263
# 158.4

# %%
avg_time = []

for i in range(len(l)):
  avg_time.append([])
  for j in range(len(l[i])):
    avg_time[i].append(sum(l[i][j])/len(l[i][j]))

print(avg_time)
# Out:
# [[153.33333333333334, 151.5, 172.14285714285714, 147.5, 156.31578947368422, 178.66666666666666, 179.41176470588235, 188.88888888888889, 190.0], [108.46153846153847, 89.21052631578948, 111.25, 110.0, 137.14285714285714, 93.25, 115.66666666666667, 84.0909090909091, 55.714285714285715], [177.6, 164.53125, 171.0, 152.72727272727272, 156.36363636363637, 136.125, 143.1081081081081, 151.44736842105263, 158.4]]

# %%
# df=pd.DataFrame(avg_time, columns=['MON', 'TUE', 'WED','THU','FRI','SAT','SUN'])
# df
# Out:
#           MON         TUE         WED         THU         FRI         SAT  \
# 0  151.000000  191.111111  167.857143  177.777778  152.400000  167.333333
# 1   66.250000  113.095238  105.294118  120.000000  102.222222  108.333333
# 2  156.538462  170.119048  120.377358  160.500000  147.391304  168.375000
#
#           SUN
# 0  171.041667
# 1   93.125000
# 2  179.545455

# %%
df=pd.DataFrame(avg_time, columns=['WEEK_1','WEEK_2','WEEK_3','WEEK_4','WEEK_5','WEEK_6','WEEK_7','WEEK_8','WEEK_9'] )
df
# Out:
#        WEEK_1      WEEK_2      WEEK_3      WEEK_4      WEEK_5      WEEK_6  \
# 0  153.333333  151.500000  172.142857  147.500000  156.315789  178.666667
# 1  108.461538   89.210526  111.250000  110.000000  137.142857   93.250000
# 2  177.600000  164.531250  171.000000  152.727273  156.363636  136.125000
#
#        WEEK_7      WEEK_8      WEEK_9
# 0  179.411765  188.888889  190.000000
# 1  115.666667   84.090909   55.714286
# 2  143.108108  151.447368  158.400000

# %%
from scipy.stats import f_oneway
f_oneway(df.WEEK_1, df.WEEK_2, df.WEEK_3,df.WEEK_4,df.WEEK_5,df.WEEK_6,df.WEEK_7,df.WEEK_8,df.WEEK_9)
# Out:
# F_onewayResult(statistic=0.07793653225388847, pvalue=0.9994991006068659)

# %%
stacked_data = df.stack().reset_index()
stacked_data = stacked_data.rename(columns={'level_0': 'id',
                                            'level_1': 'week',
                                            0:'mean_time'})
stacked_data
# Out:
#     id    week   mean_time
# 0    0  WEEK_1  153.333333
# 1    0  WEEK_2  151.500000
# 2    0  WEEK_3  172.142857
# 3    0  WEEK_4  147.500000
# 4    0  WEEK_5  156.315789
# 5    0  WEEK_6  178.666667
# 6    0  WEEK_7  179.411765
# 7    0  WEEK_8  188.888889
# 8    0  WEEK_9  190.000000
# 9    1  WEEK_1  108.461538
# 10   1  WEEK_2   89.210526
# 11   1  WEEK_3  111.250000
# 12   1  WEEK_4  110.000000
# 13   1  WEEK_5  137.142857
# 14   1  WEEK_6   93.250000
# 15   1  WEEK_7  115.666667
# 16   1  WEEK_8   84.090909
# 17   1  WEEK_9   55.714286
# 18   2  WEEK_1  177.600000
# 19   2  WEEK_2  164.531250
# 20   2  WEEK_3  171.000000
# 21   2  WEEK_4  152.727273
# 22   2  WEEK_5  156.363636
# 23   2  WEEK_6  136.125000
# 24   2  WEEK_7  143.108108
# 25   2  WEEK_8  151.447368
# 26   2  WEEK_9  158.400000

# %%
from statsmodels.formula.api import ols
results = ols('mean_time ~ C(week)', data=stacked_data).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              mean_time   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.396
# Method:                 Least Squares   F-statistic:                   0.07794
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.999
# Time:                        15:50:18   Log-Likelihood:                -133.28
# No. Observations:                  27   AIC:                             284.6
# Df Residuals:                      18   BIC:                             296.2
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
aov_table = sm.stats.anova_lm(results, typ=2)
aov_table
# Out:
#                 sum_sq    df         F    PR(>F)
# C(week)    1061.743368   8.0  0.077937  0.999499
# Residual  30652.153848  18.0       NaN       NaN

# %%
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    cols = ['sum_sq', 'df', 'mean_sq', 'F', 'PR(>F)']
    aov = aov[cols]
    return aov

anova_table(aov_table)
# Out:
#                 sum_sq    df      mean_sq         F    PR(>F)
# C(week)    1061.743368   8.0   132.717921  0.077937  0.999499
# Residual  30652.153848  18.0  1702.897436       NaN       NaN

# %%
from scipy.stats import f
f.ppf(0.99,8,18)
# Out:
# 3.705421881172038

# %% [markdown]
# ###Anova on two factors (additive)

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# df <- read.csv("cleansing_Time_spending.csv", sep=",", header=T, fileEncoding="UTF-8-BOM")
# df
# Out:
#    mean_time id day
# 1   151.0000  0 MON
# 2   191.1111  0 TUE
# 3   167.8571  0 WED
# 4   177.7778  0 THU
# 5   152.4000  0 FRI
# 6   167.3333  0 SAT
# 7   171.0417  0 SUN
# 8    66.2500  1 MON
# 9   113.0952  1 TUE
# 10  105.2941  1 WED
# 11  120.0000  1 THU
# 12  102.2222  1 FRI
# 13  108.3333  1 SAT
# 14   93.1250  1 SUN
# 15  156.5385  2 MON
# 16  170.1190  2 TUE
# 17  120.3774  2 WED
# 18  160.5000  2 THU
# 19  147.3913  2 FRI
# 20  168.3750  2 SAT
# 21  179.5455  2 SUN

# %%
# %%R
# idFactor <- factor(df$id)
# dayFactor <- factor(df$day)
# anovaResult <- aov(df$mean_time ~ idFactor + dayFactor, data=df)
# summary(anovaResult)
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# idFactor     2  18213    9106  43.939 3.01e-06 ***
# dayFactor    6   2788     465   2.242     0.11
# Residuals   12   2487     207
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# qf(0.05, 6, 12, lower.tail=F)   # day
# Out:
# [1] 2.99612

# %%
# %%R
# qf(0.05, 2, 12, lower.tail=F)   # id
# Out:
# [1] 3.885294

# %%
# %%R
# tk1 <- TukeyHSD(anovaResult, 'dayFactor', conf.level = 0.95)
# plot(tk1)

# %%
# %%R
# tk2 <- TukeyHSD(anovaResult, 'idFactor', conf.level = 0.95)
# plot(tk2)

# %%
# %%R
# boxplot(df$mean_time~df$day, horizontal=T,xlab="day", ylab="mean_time")

# %%
# %%R
# boxplot(df$mean_time~df$id, horizontal=T, xlab="id", ylab="mean_time")

# %%
import pandas as pd

# %%
with open("Time_Spending_Records.csv") as f:
  data = f.read().splitlines()
  data = data[1:] #drop header
  print(data)
# Out:
# ['04/01/2022,นอน,660,3,TUE,sleep,week 1', '04/01/2022,กินข้าวเที่ยง,120,3,TUE,Lunch,week 1', '04/01/2022,เรียน Network,180,1,TUE,Study Network,week 1', '04/01/2022,นอน,60,3,TUE,sleep,week 1', '04/01/2022,กินข้าวเย็น,60,3,TUE,Dinner,week 1', '04/01/2022,เล่นโทรศัพท์,120,2,TUE,using phone,week 1', '04/01/2022,ทำการบ้าน stat,240,1,TUE,Do homework Stat,week 1', '05/01/2022,ทำการบ้าน stat,60,1,WED,Do homework Stat,week 1', '05/01/2022,นอน,450,3,WED,sleep,week 1', '05/01/2022,เรียน Embedded,180,1,WED,Study Embedded,week 1', '05/01/2022,กินข้าวเที่ยง,60,3,WED,Lunch,week 1', '05/01/2022,เรียน Lab Network,180,1,WED,Study Lab Network,week 1', '05/01/2022,นอน,90,3,WED,sleep,week 1', '05/01/2022,กินข้าวเย็น,60,3,WED,Dinner,week 1', '05/01/2022,เล่นโทรศัพท์,90,2,WED,using phone,week 1', '05/01/2022,ทำการบ้าน Lab Network,120,1,WED,Do homework Lab Network,week 1', '05/01/2022,อ่านการ์ตูน,90,2,WED,Watch cartoon,week 1', '05/01/2022,นอน,30,3,WED,sleep,week 1', '06/01/2022,นอน,540,3,THU,sleep,week 1',
# ...

# %%
l = [[[] for i in range(7)] for j in range(3)]

for record in data:
  record = record.split(",")

  # Type 1
  if record[3] == '1':
    if record[4] == 'MON':
      l[0][0].append(int(record[2]))
    elif record[4] == 'TUE':
      l[0][1].append(int(record[2]))
    elif record[4] == 'WED':
      l[0][2].append(int(record[2]))
    elif record[4] == 'THU':
      l[0][3].append(int(record[2]))
    elif record[4] == 'FRI':
      l[0][4].append(int(record[2]))
    elif record[4] == 'SAT':
      l[0][5].append(int(record[2]))
    elif record[4] == 'SUN':
      l[0][6].append(int(record[2]))
    
  # Type 2
  elif record[3] == '2':
    if record[4] == 'MON':
      l[1][0].append(int(record[2]))
    elif record[4] == 'TUE':
      l[1][1].append(int(record[2]))
    elif record[4] == 'WED':
      l[1][2].append(int(record[2]))
    elif record[4] == 'THU':
      l[1][3].append(int(record[2]))
    elif record[4] == 'FRI':
      l[1][4].append(int(record[2]))
    elif record[4] == 'SAT':
      l[1][5].append(int(record[2]))
    elif record[4] == 'SUN':
      l[1][6].append(int(record[2]))
  
  # Type 3
  elif record[3] == '3':
    if record[4] == 'MON':
      l[2][0].append(int(record[2]))
    elif record[4] == 'TUE':
      l[2][1].append(int(record[2]))
    elif record[4] == 'WED':
      l[2][2].append(int(record[2]))
    elif record[4] == 'THU':
      l[2][3].append(int(record[2]))
    elif record[4] == 'FRI':
      l[2][4].append(int(record[2]))
    elif record[4] == 'SAT':
      l[2][5].append(int(record[2]))
    elif record[4] == 'SUN':
      l[2][6].append(int(record[2]))

print(l)
# Out:
# [[[150, 120, 60, 150, 90, 180, 150, 240, 120, 90, 150, 60, 240, 120, 180, 90, 180, 120, 180, 180, 120, 180, 210, 120, 180, 270, 120, 180, 210, 90], [180, 240, 180, 210, 120, 180, 120, 180, 240, 180, 120, 180, 200, 180, 180, 270, 180, 300], [60, 180, 180, 120, 180, 270, 60, 480, 90, 240, 120, 120, 60, 180, 60, 150, 180, 180, 180, 180, 180, 180, 180, 180, 80, 180, 180, 270], [180, 180, 300, 180, 180, 225, 120, 180, 150, 75, 150, 180, 180, 180, 120, 180, 180, 270, 180, 180, 180, 180, 180, 60, 180, 180, 270], [180, 120, 120, 150, 120, 120, 180, 90, 270, 150, 120, 60, 120, 120, 150, 120, 150, 120, 150, 240, 120, 330, 120, 120, 270], [30, 150, 150, 180, 150, 120, 240, 150, 120, 240, 150, 120, 240, 200, 270], [60, 270, 60, 135, 210, 60, 60, 180, 240, 120, 240, 240, 120, 240, 120, 120, 240, 200, 120, 240, 270, 120, 200, 240]], [[60, 90, 60, 60, 120, 60, 90, 90, 45, 30, 60, 30], [120, 120, 60, 120, 60, 30, 60, 180, 240, 60, 180, 180, 180, 100, 90, 90, 15, 250, 120, 30, 90], [90, 90, 120, 90, 
# ...

# %%
for data_class in l:
  for week in data_class:
    print(week)
    
  print()
# Out:
# [150, 120, 60, 150, 90, 180, 150, 240, 120, 90, 150, 60, 240, 120, 180, 90, 180, 120, 180, 180, 120, 180, 210, 120, 180, 270, 120, 180, 210, 90]
# [180, 240, 180, 210, 120, 180, 120, 180, 240, 180, 120, 180, 200, 180, 180, 270, 180, 300]
# [60, 180, 180, 120, 180, 270, 60, 480, 90, 240, 120, 120, 60, 180, 60, 150, 180, 180, 180, 180, 180, 180, 180, 180, 80, 180, 180, 270]
# [180, 180, 300, 180, 180, 225, 120, 180, 150, 75, 150, 180, 180, 180, 120, 180, 180, 270, 180, 180, 180, 180, 180, 60, 180, 180, 270]
# [180, 120, 120, 150, 120, 120, 180, 90, 270, 150, 120, 60, 120, 120, 150, 120, 150, 120, 150, 240, 120, 330, 120, 120, 270]
# [30, 150, 150, 180, 150, 120, 240, 150, 120, 240, 150, 120, 240, 200, 270]
# [60, 270, 60, 135, 210, 60, 60, 180, 240, 120, 240, 240, 120, 240, 120, 120, 240, 200, 120, 240, 270, 120, 200, 240]
#
# [60, 90, 60, 60, 120, 60, 90, 90, 45, 30, 60, 30]
# [120, 120, 60, 120, 60, 30, 60, 180, 240, 60, 180, 180, 180, 100, 90, 90, 15, 250, 120, 30, 90]
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()

group1=[150, 120, 60, 150, 90, 180, 150, 240, 120, 90, 150, 60, 240, 120, 180, 90, 180, 120, 180, 180, 120, 180, 210, 120, 180, 270, 120, 180, 210, 90, 180, 240, 180, 210, 120, 180, 120, 180, 240, 180, 120, 180, 200, 180, 180, 270, 180, 300 ,60, 180, 180, 120, 180, 270, 60, 480, 90, 240, 120, 120, 60, 180, 60, 150, 180, 180, 180, 180, 180, 180, 180, 180, 80, 180, 180, 270,180, 180, 300, 180, 180, 225, 120, 180, 150, 75, 150, 180, 180, 180, 120, 180, 180, 270, 180, 180, 180, 180, 180, 60, 180, 180, 270,180, 120, 120, 150, 120, 120, 180, 90, 270, 150, 120, 60, 120, 120, 150, 120, 150, 120, 150, 240, 120, 330, 120, 120, 270,30, 150, 150, 180, 150, 120, 240, 150, 120, 240, 150, 120, 240, 200, 270,60, 270, 60, 135, 210, 60, 60, 180, 240, 120, 240, 240, 120, 240, 120, 120, 240, 200, 120, 240, 270, 120, 200, 240 , 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240 ]
group2=[60, 90, 60, 60, 120, 60, 90, 90, 45, 30, 60, 30,120, 120, 60, 120, 60, 30, 60, 180, 240, 60, 180, 180, 180, 100, 90, 90, 15, 250, 120, 30, 90,90, 90, 120, 90, 60, 90, 90, 180, 90, 210, 90, 120, 60, 200, 90, 90, 30,120, 120, 75, 75, 90, 120, 210, 120, 150, 120, 120, 120,60, 150, 60, 60, 60, 60, 90, 120, 90, 30, 180, 120, 90, 90, 180, 150, 30, 180, 150, 30, 120, 270, 50, 130, 120, 60, 30,60, 300, 60, 120, 150, 120, 90, 120, 90, 120, 90, 60, 30, 45, 195, 75, 90, 60, 90, 70, 240,60, 120, 120, 90, 180, 240, 30, 30, 90, 150, 90, 70, 90, 60, 40, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,  30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30]
group3=[420, 60, 90, 120, 60, 30, 480, 60, 150, 30, 60, 570, 30, 60, 450, 60, 120, 60, 30, 510, 60, 120, 60, 30, 570, 60, 110, 70, 30, 525, 60, 120, 60, 30, 510, 60, 90, 60, 30,660, 120, 60, 60, 540, 60, 60, 660, 60, 60, 450, 30, 60, 120, 60, 510, 90, 90, 60, 30, 500, 100, 80, 70, 30, 630, 60, 10, 15, 10, 60, 30, 570, 90, 80, 70, 30, 600, 90, 80, 70, 30,450, 60, 90, 60, 30, 420, 60, 60, 360, 30, 90, 30, 15, 435, 60, 60, 540, 60, 60, 30, 405, 15, 90, 30, 60, 15, 45, 90, 30, 180, 405, 15, 90, 30, 60, 20, 80, 90, 30, 315, 15, 90, 30, 60, 20, 60, 90, 30, 200, 540, 60, 60, 30,540, 60, 60, 420, 60, 75, 90, 15, 420, 30, 60, 60, 30, 150, 570, 60, 60, 30, 60, 540, 60, 60, 30, 540, 60, 60, 30, 540, 60, 60, 30, 540, 60, 60, 30, 540, 60, 120, 60, 30,330, 30, 90, 90, 450, 60, 120, 60, 630, 30, 60, 60, 90, 330, 150, 60, 60, 60, 30, 570, 30, 30, 90, 30, 60, 30, 540, 60, 90, 60, 30, 540, 60, 60, 30, 540, 60, 150, 60, 30, 570, 30, 60, 90, 60, 30,450, 30, 90, 180, 60, 150, 630, 60, 150, 90, 60, 120, 690, 60, 60, 30, 540, 60, 90, 30, 540, 60, 90, 30, 450, 30, 60, 90, 15, 60, 30, 540, 60, 90, 30, 690, 60, 90, 60, 30,540, 120, 30, 600, 45, 60, 60, 60, 540, 60, 60, 30, 540, 60, 90, 90, 30, 540, 60, 90, 30, 540, 60, 90, 30, 540, 60, 90, 30, 600, 60, 60, 30]

# colors = {'MON':'yellow','TUE':'pink','WED':'green','THU':'orange','FRI':'cyan','SAT':'purple','SUN':'red'}

ax.scatter(group1,group2, facecolor ='orange')

ax.scatter(group2,group3, facecolor ='purple')

ax.scatter(group1,group3, facecolor ='cyan')

ax.set_title("duration of activity between group")

plt.show()
